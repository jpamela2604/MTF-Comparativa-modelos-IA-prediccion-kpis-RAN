# %% [markdown]
# # TRABAJO FINAL DE MAESTRIA

# %%
# Importar de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Modelado
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neural_network import MLPRegressor
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)
import random;
#carga de los archivos que representan los dataset
import glob
import os

# %%
# Semillas para reproducibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
print(f"Semilla de aleatoriedad global fijada en: {SEED}")
# Out:
# Semilla de aleatoriedad global fijada en: 42

# %%
ruta_archivos = "./dataset/2025*.csv"
archivos = sorted(glob.glob(ruta_archivos))

dataframes = []
ids = []  # aquí vamos a guardar los IDs de grupo

for i, archivo in enumerate(archivos, start=1):
    df_temp = pd.read_csv(archivo)
    df_temp['grupo'] = i  # asignamos ID de grupo a cada fila
    dataframes.append(df_temp)

# Unir todo en un solo DataFrame
df_total = pd.concat(dataframes, ignore_index=True)

print(f"Dimensiones del dataset combinado: {df_total.shape}")
print(f"Grupos únicos cargados: {df_total['grupo'].nunique()}")
# Out:
# Dimensiones del dataset combinado: (59798, 15)
# Grupos únicos cargados: 10

# %%
df_total.head()
# Out:
#            time  phy_mcs  mac_dl_cqi  mac_dl_ri  mac_dl_pmi  mac_ul_buffer  \
# 0  1.743169e+12      0.0         9.0        1.0         3.0       4.666667
# 1  1.743169e+12      0.0         9.0        1.0         3.0       4.666667
# 2  1.743169e+12      0.0         9.0        1.0         3.0       0.000000
# 3  1.743169e+12      0.0         9.0        1.0         3.0       0.000000
# 4  1.743169e+12      0.0         9.0        1.0         3.0       0.000000
#
#    mac_n_prb      rsrq  rsrp  rssi  dl_sinr        se  dl_bler  delay  grupo
# 0        2.0 -6.700000 -88.0 -68.0     20.0  0.002000      0.0   -1.0      1
# 1        4.0 -6.733333 -88.0 -68.0     20.0  0.008747      0.0   -1.0      1
# 2        6.0 -6.733333 -88.0 -68.0     20.0  0.008747      0.0   -1.0      1
# 3       12.0 -6.866667 -88.0 -68.0     20.0  0.027413      0.0   -1.0      1
# 4       16.0 -6.866667 -88.0 -68.0     20.0  0.020667      0.0   -1.0      1

# %% [markdown]
# VERIFICAR VALORES NULOS

# %%
nulos_por_columna = df_total.isnull().sum()
print("Valores nulos por columna:")
print(nulos_por_columna)
# Out:
# Valores nulos por columna:
# time             0
# phy_mcs          0
# mac_dl_cqi       0
# mac_dl_ri        0
# mac_dl_pmi       0
# mac_ul_buffer    0
# mac_n_prb        0
# rsrq             0
# rsrp             0
# rssi             0
# dl_sinr          0
# se               0
# dl_bler          0
# delay            0
# grupo            0
# dtype: int64

# %% [markdown]
# | Variable        | Descripción                                                                                                                                                                                                |
# | --------------- | ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | `time`          | Marca de tiempo en milisegundos (UNIX epoch), que indica el momento exacto de cada medición.                                                                                                               |
# | `phy_mcs`       | Índice de modulación y codificación (MCS), utilizado para determinar la velocidad y calidad de transmisión en downlink. Valores más altos implican mayor velocidad, pero requieren mejor calidad de señal. |
# | `mac_dl_cqi`    | Indicador de calidad del canal (CQI) en downlink, reportado por el usuario. Valores más altos indican mejor calidad de señal.                                                                              |
# | `mac_dl_ri`     | Indicador de rango espacial (RI) en downlink, que representa la cantidad de flujos espaciales simultáneos soportados por la transmisión MIMO.                                                              |
# | `mac_dl_pmi`    | Índice de precodificación (PMI) en downlink, que permite a la red orientar la señal hacia el usuario mediante técnicas de beamforming.                                                                     |
# | `mac_ul_buffer` | Ocupación del búfer de subida (uplink) del usuario en bytes. Refleja la cantidad de datos pendientes de envío; valores altos pueden indicar congestión.                                                    |
# | `mac_n_prb`     | Número de bloques de recursos físicos (PRBs) asignados al usuario en downlink para la transmisión de datos.                                                                                                |
# | `rsrq`          | Calidad de señal de referencia recibida (RSRQ) en dB, considerando tanto la potencia de la señal como el ruido de fondo.                                                                                   |
# | `rsrp`          | Potencia de la señal de referencia (RSRP) en dBm, sin incluir ruido; útil para evaluar cobertura en downlink.                                                                                              |
# | `rssi`          | Potencia total de señal recibida (RSSI) en dBm, incluyendo tanto la señal útil como el ruido.                                                                                                              |
# | `dl_sinr`       | Relación señal/interferencia+ruido (SINR) medida por el usuario en downlink. Cuanto más alta, mejor la calidad de la señal.                                                                                |
# | `se`            | Eficiencia espectral en downlink, expresada en bits por segundo por hercio (bps/Hz); indica cuán eficientemente se utiliza el ancho de banda disponible.                                                   |
# | `dl_bler`       | Tasa de bloques erróneos (BLER) en downlink; representa el porcentaje de bloques que deben retransmitirse por errores.                                                                                     |
# | `delay`         | Retardo unidireccional del paquete RTP (latencia), en milisegundos; indica cuánto ta                                                                                                                       |

# %% [markdown]
# ## PREPARACION DE DATOS

# %%
#eliminar variable "time"
df_total = df_total.drop(columns=['time'])
print("Dimensiones del dataset:", df_total.shape)
df_total.info()
df_total.describe()

#hacer matriz de correlacion
plt.figure(figsize=(12, 8))
sns.heatmap(df_total.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de correlación entre KPIs")
plt.savefig("correlacion_kpis.png", dpi=300, bbox_inches='tight') 
plt.show()
# Out:
# Dimensiones del dataset: (59798, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59798 entries, 0 to 59797
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   phy_mcs        59798 non-null  float64
#  1   mac_dl_cqi     59798 non-null  float64
#  2   mac_dl_ri      59798 non-null  float64
#  3   mac_dl_pmi     59798 non-null  float64
#  4   mac_ul_buffer  59798 non-null  float64
#  5   mac_n_prb      59798 non-null  float64
#  6   rsrq           59798 non-null  float64
#  7   rsrp           59798 non-null  float64
#  8   rssi           59798 non-null  float64
#  9   dl_sinr        59798 non-null  float64
#  10  se             59798 non-null  float64
#  11  dl_bler        59798 non-null  float64
#  12  delay          59798 non-null  float64
#  13  grupo          59798 non-null  int64
# dtypes: float64(13), int64(1)
# memory usage: 6.4 MB

# %% [markdown]
# ### Validación de datos Atípicos

# %%
def validarAtipicos(df, columnName, especification):
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=df[columnName])
    plt.title('Diagrama de caja de ' + especification)
    plt.savefig("DiagramaCaja_"+columnName+".png", dpi=300, bbox_inches='tight')
    plt.show()
    
    Q1 = df[columnName].quantile(0.25)
    Q3 = df[columnName].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    
    print(f"Q1: {Q1}, Q3: {Q3}, IQR: {IQR}")
    print(f"Límite inferior: {limite_inferior}, Límite superior: {limite_superior}")
    
    outliers = df[(df[columnName] < limite_inferior) | (df[columnName] > limite_superior)]
    cantidad = len(outliers)
    porcentaje = (cantidad / len(df)) * 100
    print(f"Cantidad de registros relacionados con  {especification} que serían eliminados: {cantidad} / {len(df)} ({porcentaje:.2f}%)")
    
    return limite_inferior, limite_superior


def eliminarAtipicos(df, columnName, limite_inferior, limite_superior):
    df_sin_outliers = df[(df[columnName] >= limite_inferior) & (df[columnName] <= limite_superior)]
    print(f"Registros después de eliminar outliers: {len(df_sin_outliers)} / {len(df)}")
    return df_sin_outliers

# %%
lim_inf1, lim_sup1 = validarAtipicos(df_total,'se','Eficiencia espectral')
# Out:
# Q1: 0.31114166666666665, Q3: 0.7693866666666667, IQR: 0.458245
# Límite inferior: -0.37622583333333337, Límite superior: 1.4567541666666668
# Cantidad de registros relacionados con  Eficiencia espectral que serían eliminados: 1922 / 59798 (3.21%)

# %%
lim_inf2, lim_sup2 =validarAtipicos(df_total,'mac_ul_buffer','Ocupación del búfer')
# Out:
# Q1: 0.0, Q3: 0.0, IQR: 0.0
# Límite inferior: 0.0, Límite superior: 0.0
# Cantidad de registros relacionados con  Ocupación del búfer que serían eliminados: 14939 / 59798 (24.98%)

# %% [markdown]
# *Eliminar valores atipicos*

# %%
df_total = eliminarAtipicos(df_total, 'se', lim_inf1, lim_sup1)
# Out:
# Registros después de eliminar outliers: 57876 / 59798

# %% [markdown]
#  Normalizar el conjunto de datos (excepto 'grupo')

# %%
scaler = StandardScaler()
columnas_a_normalizar = df_total.drop(columns=['grupo']).columns
df_total[columnas_a_normalizar] = scaler.fit_transform(df_total[columnas_a_normalizar])

# %% [markdown]
# Separar features, target y grupos

# %%
X = df_total.drop(columns=['se', 'grupo'])
y = df_total['se']
groups = df_total['grupo'].values

# %% [markdown]
# ## Entrenamiento de modelos

# %% [markdown]
# ### REGRESION LINEAL

# %%
# Config GroupKFold
gkf = GroupKFold(n_splits=int(1/(1-0.7)))  # 70/30 → 3 splits aprox

# iniciar lista métricas
mae_list = []
rmse_list = []
r2_list = []

# ejecutar validacion gruzada
fold = 1
for train_idx, test_idx in gkf.split(X, y, groups=groups):
    print(f"\n--- Fold {fold} ---")

    # Dividir datos por grupos
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    # Entrenar modelo
    modelo_regresion = LinearRegression()
    modelo_regresion.fit(X_train, y_train)

    # Predecir
    y_pred = modelo_regresion.predict(X_test)

    # Calcular métricas
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    # Guardar métricas en lsitas
    mae_list.append(mae)
    rmse_list.append(rmse)
    r2_list.append(r2)

    # Mostrar métricas de este fold
    print(f"MAE: {mae:.2f} | RMSE: {rmse:.2f} | R2: {r2:.2f}")

    fold += 1

print("\nResumen validación cruzada por grupos para regresión lineal")
print(f"MAE promedio: {np.mean(mae_list):.2f}")
print(f"RMSE promedio: {np.mean(rmse_list):.2f}")
print(f"R2 promedio: {np.mean(r2_list):.2f}")
# Out:
# --- Fold 1 ---
# MAE: 0.51 | RMSE: 0.63 | R2: 0.60
#
# --- Fold 2 ---
# MAE: 0.54 | RMSE: 0.66 | R2: 0.60
#
# --- Fold 3 ---
# MAE: 0.49 | RMSE: 0.63 | R2: 0.58
#
# Resumen validación cruzada por grupos para regresión lineal
# MAE promedio: 0.51
# RMSE promedio: 0.64
# R2 promedio: 0.60

# %% [markdown]
# ### MODELO RANDOM FOREST

# %%
# Config GroupKFold
gkf = GroupKFold(n_splits=int(1/(1-0.7)))  # 70/30 ≈ 3 folds

# Parámetros del modelo
param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10]
}

# iniciar lista métricas
mae_list = []
rmse_list = []
r2_list = []
best_params_folds = []
fold = 1
for train_idx, test_idx in gkf.split(X, y, groups=groups):
    print(f"\n--- Fold {fold} ---")

    # Dividir datos por grupos
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    # Crear y entrenar modelo con GridSearch
    modelo = RandomForestRegressor(random_state=SEED)
    grid_search = GridSearchCV(estimator=modelo, param_grid=param_grid, cv=3, scoring='r2', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    mejor_modelo = grid_search.best_estimator_
    mejor_parametros = grid_search.best_params_
    print("Mejores parámetros encontrados por Grid Search:")
    print(mejor_parametros)

    # Predecir
    y_pred = mejor_modelo.predict(X_test)

     # Guardar los mejores parámetros del fold
    best_params = grid_search.best_params_
    best_params_folds.append(best_params)
    print("Mejores parámetros de este fold:", best_params)

    # Calcular métricas
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    # Guardar métricas en listas
    mae_list.append(mae)
    rmse_list.append(rmse)
    r2_list.append(r2)

    # Mostrar métricas de este fold
    print(f"MAE: {mae:.2f} | RMSE: {rmse:.2f} | R2: {r2:.2f}")

    fold += 1


print("\nResumen validación cruzada por grupos para Random Forest")
print(f"MAE promedio: {np.mean(mae_list):.2f}")
print(f"RMSE promedio: {np.mean(rmse_list):.2f}")
print(f"R2 promedio: {np.mean(r2_list):.2f}")
# Out:
# --- Fold 1 ---
# Mejores parámetros encontrados por Grid Search:
# {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200}
# Mejores parámetros de este fold: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200}
# MAE: 0.25 | RMSE: 0.38 | R2: 0.85
#
# --- Fold 2 ---
# Mejores parámetros encontrados por Grid Search:
# {'max_depth': 15, 'min_samples_split': 10, 'n_estimators': 100}
# Mejores parámetros de este fold: {'max_depth': 15, 'min_samples_split': 10, 'n_estimators': 100}
# MAE: 0.28 | RMSE: 0.41 | R2: 0.85
#
# --- Fold 3 ---
# Mejores parámetros encontrados por Grid Search:
# {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 200}
# Mejores parámetros de este fold: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 200}
# MAE: 0.30 | RMSE: 0.47 | R2: 0.77
#
# Resumen validación cruzada por grupos para Random Forest
# MAE promedio: 0.28
# RMSE promedio: 0.42
# R2 promedio: 0.82

# %% [markdown]
# ### MODELO MULTIPLAYER PERCEPTRON (MLP)

# %%
# Config GroupKFold
gkf = GroupKFold(n_splits=int(1/(1-0.7)))  # 70/30 ≈ 3 folds

# Parámetros del modelo
param_grid_mlp = {
    'hidden_layer_sizes': [(100,), (50, 50), (100, 50, 25)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam'],
    'alpha': [0.0001, 0.001],
    'max_iter': [500]
}

# variables
mae_list = []
rmse_list = []
r2_list = []
best_params_folds_mlp = []

fold = 1
for train_idx, test_idx in gkf.split(X, y, groups=groups):
    print(f"\n--- Fold {fold} ---")

    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    # GridSearchCV para MLP
    mlp_model = MLPRegressor(random_state=SEED)
    grid_mlp = GridSearchCV(mlp_model, param_grid_mlp, cv=3, scoring='r2', n_jobs=-1)
    grid_mlp.fit(X_train, y_train)

    # Guardar los mejores parámetros de este fold
    best_params = grid_mlp.best_params_
    best_params_folds_mlp.append(best_params)
    print("Mejores hiperparámetros de este fold:", best_params)

    # Predecir y calcular métricas
    y_pred = grid_mlp.best_estimator_.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    mae_list.append(mae)
    rmse_list.append(rmse)
    r2_list.append(r2)

    print(f"MAE: {mae:.2f} | RMSE: {rmse:.2f} | R2: {r2:.2f}")

    fold += 1

print("\nResumen validación cruzada por grupos para MLP")
print(f"MAE promedio: {np.mean(mae_list):.2f}")
print(f"RMSE promedio: {np.mean(rmse_list):.2f}")
print(f"R2 promedio: {np.mean(r2_list):.2f}")
# Out:
# --- Fold 1 ---
# Mejores hiperparámetros de este fold: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'max_iter': 500, 'solver': 'adam'}
# MAE: 0.37 | RMSE: 0.50 | R2: 0.74
#
# --- Fold 2 ---
# Mejores hiperparámetros de este fold: {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 500, 'solver': 'adam'}
# MAE: 0.33 | RMSE: 0.45 | R2: 0.82
#
# --- Fold 3 ---
# Mejores hiperparámetros de este fold: {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 500, 'solver': 'adam'}
# MAE: 0.35 | RMSE: 0.50 | R2: 0.74
#
# Resumen validación cruzada por grupos para MLPP
# MAE promedio: 0.35
# RMSE promedio: 0.48
# R2 promedio: 0.77
